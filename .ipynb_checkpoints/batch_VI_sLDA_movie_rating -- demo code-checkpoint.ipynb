# %%
import os
import pickle
import numpy as np
from text_processing_utils import *
import glob
import datetime as dt
import math
from variational_inference_sLDA_M_step import *
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
start_time = dt.datetime.now()

# %% [markdown]
# #### Prepare the data

# %% [markdown]
# Those input data were created by running the Jupyter Notebook "processing_movie_reviews_rating_scale_data.ipynb".

# %%
cleaned_ratings = np.array(pickle.load(open("data/scaledata/cleaned_ratings.pickle", "rb")))
cleaned_reviews = pickle.load(open("data/scaledata/cleaned_reviews.pickle", "rb"))
vocabulary_dict = pickle.load(open("data/scaledata/vocabulary_dict.pickle", "rb"))

# %%
# randomly split the movie reviews data into training/testing parts (10:90)
np.random.seed(54321)
training_set_ratio = 0.1 # for demonstration purposes, we randomly take a very small training sample
train_indices = np.random.choice(np.arange(len(cleaned_ratings)), int(len(cleaned_ratings)*training_set_ratio), replace=False)
test_indices = np.setdiff1d(np.arange(len(cleaned_ratings)), train_indices)
print(len(train_indices), len(test_indices))
train_bow = convert_bow([cleaned_reviews[i] for i in train_indices])
test_bow = convert_bow([cleaned_reviews[i] for i in test_indices])
train_y = cleaned_ratings[train_indices]
test_y = cleaned_ratings[test_indices]
# Out:
# 500 4506

# %% [markdown]
# #### Train sLDA model on movie rating data using batch variational inference

# %%
K = 12 # number of topics
V = len(vocabulary_dict) # vocabulary size

# %%
## initialization
np.random.seed(12345)
new_alpha = np.array([1/K]*K)
new_xi = np.array([1/V]*V)
new_eta = np.linspace(-1,1,K)
new_delta = np.var(train_y, ddof=1)
new_Lambda = np.abs(np.random.normal(loc=0, scale=0.1, size=K*V)).reshape((K,V)) # initialize Lambda randomly (add a small half-normal distribution to 1)
input_data_x = train_bow
input_data_y = train_y
fpath = "fragmented_output_files/" # where to store the temporary fragmented files during parallelized E steps
if not os.path.exists(fpath[:-1]):
    os.makedirs(fpath[:-1])
else:
    delete_all_files(fpath[:-1]) # if the directory exists, we delete all temporary files in it
epsilon = 1e-4 # stopping criteria for convergence in E step
predict = False
## Run batch mode variational EM
elbo_vs_time = [-math.inf]
improve_in_elbo = math.inf
time_elapsed = 0
j = 0
while improve_in_elbo > 0.01: # We consider the variational EM procedure converges when the improvement in corpus-level elbo becomes smaller than 0.01%

    ### Run one iteration of E step (parallelized)
    # %run -i "parallelized_sLDA_E_step.py"
    all_gamma = [pickle.load(open(fn, "rb")) for fn in glob.glob(fpath + "gamma*")]
    new_gamma_dict = merge_dict(all_gamma)
    new_gamma = create_gamma_matrix(new_gamma_dict)
    all_phi = [pickle.load(open(fn, "rb")) for fn in glob.glob(fpath + "phi*")]
    new_phi = merge_dict(all_phi)

    ### Run one iteration of M step
    m_step = batch_VI_sLDA_M_Step(K, train_bow, train_y,
                                  new_alpha, new_xi, new_eta, new_delta, new_Lambda,
                                  new_gamma, new_phi,
                                  len(train_bow), 1e-4)
    new_Lambda, new_alpha, new_xi, new_eta, new_delta, new_elbo = m_step.run()
    improve_in_elbo = pct_diff(elbo_vs_time[-1], new_elbo)
    elbo_vs_time.append(new_elbo)
    current_time = dt.datetime.now()
    time_elapsed = (current_time - start_time).seconds
    j += 1
    print("Complete variational EM iteration {}: ELBO =".format(j), new_elbo)

## save final results to disk
output_dir = "batch_VI_sLDA_movie_rating/K_{}".format(K)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
for var in ['Lambda', 'alpha', 'xi', 'eta', 'delta']: # save all global parameters
    pickle.dump(eval("new_"+var), open(output_dir + "/{}.pickle".format(var), "wb"))
pickle.dump(elbo_vs_time, open(output_dir + "/{}.pickle".format("elbo_vs_time"), "wb"))
pickle.dump(time_elapsed, open(output_dir + "/{}.pickle".format("time_elapsed"), "wb"))
# Out:
# Complete variational EM iteration 1: ELBO = -1068795.5800750256
# Complete variational EM iteration 2: ELBO = -872108.7466402054
# Complete variational EM iteration 3: ELBO = -817783.9922623634
# Complete variational EM iteration 4: ELBO = -794097.2527601719
# Complete variational EM iteration 5: ELBO = -780853.0698652267
# Complete variational EM iteration 6: ELBO = -772099.3236846924
# Complete variational EM iteration 7: ELBO = -765679.272195816
# Complete variational EM iteration 8: ELBO = -760629.9053235054
# Complete variational EM iteration 9: ELBO = -756621.4791941643
# Complete variational EM iteration 10: ELBO = -753298.0501506329
# Complete variational EM iteration 11: ELBO = -750510.20181036
# Complete variational EM iteration 12: ELBO = -747968.3672845364
# Complete variational EM iteration 13: ELBO = -745741.4883310795
# Complete variational EM iteration 14: ELBO = -743777.193779707
# Complete variational EM iteration 15: ELBO = -741928.5422315598
# Complete variational EM iteration 16: ELBO = -740283.6289782524
# Complete variational EM iteration 17: ELBO = -738746.9098016024
# Complete variational EM iteration 18: ELBO = -737281.8421736956
# Complete variational EM iteration 19: ELBO = -735947.4877150059
# Complete variational EM iteration 20: ELBO = -734655.3030967712
# Complete variational EM iteration 21: ELBO = -733426.589168191
# Complete variational EM iteration 22: ELBO = -732263.356742382
# Complete variational EM iteration 23: ELBO = -731156.8184680939
# Complete variational EM iteration 24: ELBO = -730065.5462875366
# Complete variational EM iteration 25: ELBO = -729011.0900018215
# Complete variational EM iteration 26: ELBO = -728009.4431515932
# Complete variational EM iteration 27: ELBO = -727052.1312372684
# Complete variational EM iteration 28: ELBO = -726096.1042478085
# Complete variational EM iteration 29: ELBO = -725172.0995895863
# Complete variational EM iteration 30: ELBO = -724297.5194979906
# Complete variational EM iteration 31: ELBO = -723433.5248092413
# Complete variational EM iteration 32: ELBO = -722586.0078151226
# Complete variational EM iteration 33: ELBO = -721764.4099911451
# Complete variational EM iteration 34: ELBO = -720962.9368972778
# Complete variational EM iteration 35: ELBO = -720181.2675231695
# Complete variational EM iteration 36: ELBO = -719416.7942804098
# Complete variational EM iteration 37: ELBO = -718668.3442358971
# Complete variational EM iteration 38: ELBO = -717940.0326521397
# Complete variational EM iteration 39: ELBO = -717226.7111160755
# Complete variational EM iteration 40: ELBO = -716528.9698064327
# Complete variational EM iteration 41: ELBO = -715854.2065374851
# Complete variational EM iteration 42: ELBO = -715190.2080186605
# Complete variational EM iteration 43: ELBO = -714543.8681805134
# Complete variational EM iteration 44: ELBO = -713912.0719491243
# Complete variational EM iteration 45: ELBO = -713295.4058274031
# Complete variational EM iteration 46: ELBO = -712698.1054064035
# Complete variational EM iteration 47: ELBO = -712114.830975771
# Complete variational EM iteration 48: ELBO = -711549.2327125072
# Complete variational EM iteration 49: ELBO = -710997.11911273
# Complete variational EM iteration 50: ELBO = -710454.9026525021
# Complete variational EM iteration 51: ELBO = -709938.8119753599
# Complete variational EM iteration 52: ELBO = -709444.6534382105
# Complete variational EM iteration 53: ELBO = -708970.3410067558
# Complete variational EM iteration 54: ELBO = -708513.7551785707
# Complete variational EM iteration 55: ELBO = -708073.6755729914
# Complete variational EM iteration 56: ELBO = -707650.2631105185
# Complete variational EM iteration 57: ELBO = -707244.647274375
# Complete variational EM iteration 58: ELBO = -706855.3911554813
# Complete variational EM iteration 59: ELBO = -706483.7577742338
# Complete variational EM iteration 60: ELBO = -706127.0405107737
# Complete variational EM iteration 61: ELBO = -705789.2762970924
# Complete variational EM iteration 62: ELBO = -705467.2681918144
# Complete variational EM iteration 63: ELBO = -705160.0801876783
# Complete variational EM iteration 64: ELBO = -704871.5651026964
# Complete variational EM iteration 65: ELBO = -704599.0042665005
# Complete variational EM iteration 66: ELBO = -704339.7538605928
# Complete variational EM iteration 67: ELBO = -704092.6081656218
# Complete variational EM iteration 68: ELBO = -703859.5360581875
# Complete variational EM iteration 69: ELBO = -703640.9191652536
# Complete variational EM iteration 70: ELBO = -703437.4752274752
# Complete variational EM iteration 71: ELBO = -703244.442131877
# Complete variational EM iteration 72: ELBO = -703062.7371743917
# Complete variational EM iteration 73: ELBO = -702894.5586832762
# Complete variational EM iteration 74: ELBO = -702738.8696502447
# Complete variational EM iteration 75: ELBO = -702593.5660748482
# Complete variational EM iteration 76: ELBO = -702458.7630491257
# Complete variational EM iteration 77: ELBO = -702333.5785788298
# Complete variational EM iteration 78: ELBO = -702217.4924610853
# Complete variational EM iteration 79: ELBO = -702111.4332338572
# Complete variational EM iteration 80: ELBO = -702012.567902565
# Complete variational EM iteration 81: ELBO = -701921.3915258646
# Complete variational EM iteration 82: ELBO = -701837.5402286053
# Complete variational EM iteration 83: ELBO = -701760.2500070333
# Complete variational EM iteration 84: ELBO = -701690.2908987999

# %%
print("Time used to fit the sLDA model:", int(time_elapsed / 60), "minutes")
# Out:
# Time used to fit the sLDA model: 56 minutes

# %%
plt.plot(np.arange(1, len(elbo_vs_time)), elbo_vs_time[1:])
plt.xlabel("Variation EM Iteration")
plt.ylabel("Corpus-level ELBO")
plt.show()

# %%
# Top  words of each topic learned from training sLDA, with its corresponding coefficient (eta)
top_n = 10 # Top n words from each topic
inverse_vocabulary_dict = {v:k for k,v in vocabulary_dict.items()}
for t in range(K):
    word_indices = np.argsort(new_Lambda[t,:])[::-1][:top_n]
    print("Topic {}:".format(t+1), [inverse_vocabulary_dict[j] for j in word_indices], "eta =", new_eta[t])
# Out:
# Topic 1: ['us', 'especially', 'screen', 'long', 'another', 'over', 'perhaps', 'last', 'fact', 'becomes'] eta = 0.35297650512243806
# Topic 2: ['movies', 'violence', 'world', 'cast', 'sex', 'where', 'comes', 'effects', 'michael', 'language'] eta = 0.494086521486123
# Topic 3: ['hard', 're', 'line', 'r', 'every', 'great', 'style', 'sure', 'subject', 'said'] eta = 0.43697678328137
# Topic 4: ['year', 'nothing', 'quite', 'interesting', 'plays', 'full', 'watch', 'tale', 'clear', 'robert'] eta = 0.36679218536144376
# Topic 5: ['both', 'role', 'less', 'david', 'through', 'own', 'cinematography', 'yet', 'sometimes', 'half'] eta = 0.9697808654288718
# Topic 6: ['action', 'star', 'big', 'actually', 'right', 'moments', 'going', 'result', 'certainly', 'watching'] eta = 1.110329627130687
# Topic 7: ['kids', 'motion', 'minutes', 'play', 'however', 'thought', 'together', 'pictures', 'fine', 'once'] eta = 0.7515433313367925
# Topic 8: ['special', 'effective', 'age', 'humor', 'everything', 'three', 'production', 'use', 'human', 'sort'] eta = 0.7265944959918968
# Topic 9: ['comedy', 'bad', 'plot', 'scene', 'funny', 'seen', 'making', 'come', 've', 'here'] eta = 0.3164777343285756
# Topic 10: ['man', 'him', 'down', 'real', 'high', 'seem', 'performances', 'same', 'original', 'hollywood'] eta = 0.5871087713338632
# Topic 11: ['love', 'acting', 'john', 'really', 'think', 'between', 'then', 'things', 'still', 'end'] eta = 0.5247555593254187
# Topic 12: ['though', 'sense', 'point', 'give', 'excellent', 'ca', 'times', 'actors', 'bit', 'money'] eta = 0.480447907553458

# %% [markdown]
# #### Prediction and Evaluation on the Test Set

# %%
input_data_x = test_bow
input_data_y = test_y
fpath = "fragmented_output_files_new/" # where to store the temporary fragmented files during parallelized E steps
if not os.path.exists(fpath[:-1]):
    os.makedirs(fpath[:-1])
else:
    for fn in glob.glob(fpath + "*"):
        os.remove(fn)
epsilon = 1e-4 # stopping criteria for convergence in E step
predict = True # prediction mode for evaluating the test set

## Run one iteration of unsupervised E step (parallelized) to identify the optimal local variational parameters for all documents in the test set.
## The optimized phi identified from the unsupervised batch VI will be used to generate the predictions for response variable y in the test set
# %run -i "parallelized_sLDA_E_step.py" # unsupervised batch VI for sLDA is way faster than supervised one
all_gamma = [pickle.load(open(fn, "rb")) for fn in glob.glob(fpath + "gamma*")]
new_gamma_dict = merge_dict(all_gamma)
new_gamma = create_gamma_matrix(new_gamma_dict)
all_phi = [pickle.load(open(fn, "rb")) for fn in glob.glob(fpath + "phi*")]
new_phi = merge_dict(all_phi)

# %%
# Generate predictions for the response variable y for the test set:
# For Gaussian response, y_hat = E[phi_bar^T eta]
phi_bar = {k:v.mean(axis=0) for k,v in new_phi.items()}
pred_y = np.empty((len(test_y),))
for indx in range(len(test_y)):
    pred_y[indx] = np.dot(phi_bar[indx], new_eta)

# %%
# performance metrics: 
def predictive_R2(test_y, pred_y):
    return 1 - np.mean((test_y - pred_y)**2) / np.var(test_y)

print("Predictive R^2 =", predictive_R2(test_y, pred_y))
print("Pearson correlation coefficient =", pearsonr(test_y, pred_y).statistic)
# Out:
# Predictive R^2 = 0.01016739583047599
# Pearson correlation coefficient = 0.11927797659064812

# %%
# Compare the predicted histogram of predicted vs. actual y values 
plt.hist(pred_y, alpha=0.5, label='x')
plt.hist(test_y, alpha=0.5, label='y')
plt.legend(['predicted y', 'actual_y'], loc='upper right')
plt.show()
