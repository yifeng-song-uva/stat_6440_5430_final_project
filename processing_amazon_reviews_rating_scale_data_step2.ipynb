# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pickle
from text_processing_utils import * # upload the script text_processing_utils.py to the same directory of this Google Colab notebook

# %%
# the two files generated in step 1, which are uploaded to the home directory of my Google Drive
all_vocabulary_dict = pickle.load(open("/content/drive/MyDrive/all_vocabulary_dict.pickle", "rb"))
reviews = pickle.load(open("/content/drive/MyDrive/reviews.pickle", "rb"))

# %%
# Replace words in the corpus by their indices in the entire vocabulary
reviews_new = []
for r in reviews:
    wl = np.array([all_vocabulary_dict[v] for v in tokenize(r)])
    reviews_new.append(wl)

# %%
pickle.dump(reviews_new, open("/content/drive/MyDrive/reviews_new.pickle", "wb"))
