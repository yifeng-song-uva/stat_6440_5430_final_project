# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import pickle
import numpy as np
from text_processing_utils import *
from variational_inference_utils import *
import glob
import math
from variational_inference_sLDA_M_step_diagnostics_2 import *

# %%
cleaned_ratings = np.array(pickle.load(open("/content/drive/MyDrive/data/scaledata/cleaned_ratings.pickle", "rb")))
cleaned_reviews = pickle.load(open("/content/drive/MyDrive/data/scaledata/cleaned_reviews.pickle", "rb"))
vocabulary_dict = pickle.load(open("/content/drive/MyDrive/data/scaledata/vocabulary_dict.pickle", "rb"))

# %%
# split the movie reviews data into training/testing parts (80:20)
np.random.seed(54321)
train_indices = np.random.choice(np.arange(len(cleaned_ratings)), int(len(cleaned_ratings)*0.8), replace=False)
test_indices = np.setdiff1d(np.arange(len(cleaned_ratings)), train_indices)
print(len(train_indices), len(test_indices))
train_bow = convert_bow([cleaned_reviews[i] for i in train_indices])
test_bow = convert_bow([cleaned_reviews[i] for i in test_indices])
train_y = cleaned_ratings[train_indices]
test_y = cleaned_ratings[test_indices]
# Out:
# 4004 1002

# %%
K = 24 # number of topics
V = len(vocabulary_dict) # vocabulary size
output_dir = "/content/drive/MyDrive/data/scaledata/diagnostic_5"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
else:
    delete_all_files(output_dir)
fpath = "fragmented_output_files_5/" # where to store the temporary fragmented files during parallelized E steps
if not os.path.exists(fpath[:-1]):
    os.makedirs(fpath[:-1])
else:
    delete_all_files(fpath[:-1])

# %%
## Initialization of parameters
np.random.seed(1234567)
initial_batch_size = 1000
sample_indices = np.random.choice(np.arange(len(train_bow)), initial_batch_size, replace=False)
train_bow_sample = {new_i:train_bow[new_i] for new_i,i in enumerate(sample_indices)}
train_y_sample = train_y[sample_indices]
input_data_x = train_bow_sample
input_data_y = train_y_sample
predict = False
np.random.seed(12345)
new_alpha = np.array([1/K]*K)
new_xi = np.array([1/V]*V)
new_eta = np.linspace(-1,1,K)
new_delta = np.var(train_y, ddof=1)
new_Lambda = np.abs(np.random.normal(loc=0, scale=0.1, size=K*V)).reshape((K,V)) # initialize Lambda randomly (add a small half-normal distribution to 1)
epsilon = 1e-4
elbo_epsilon=0.01 # percentage

## Run batch mode variational EM on a randomly selected sample with moderately large size (1000) to initialize (warm-up) the stochastic procedure
elbo_vs_time = [-math.inf]
improve_in_elbo = math.inf
j = 0 # record total # of warm-up variational EM iterations
while improve_in_elbo > elbo_epsilon:
    ### Run one iteration of E step (parallelized)
    # %run -i "parallelized_sLDA_E_step.py"
    all_gamma = [pickle.load(open(fn, "rb")) for fn in glob.glob(fpath + "gamma*")]
    new_gamma_dict = merge_dict(all_gamma)
    new_gamma = create_gamma_matrix(new_gamma_dict)
    all_phi = [pickle.load(open(fn, "rb")) for fn in glob.glob(fpath + "phi*")]
    new_phi = merge_dict(all_phi)
    ### Run one iteration of M step
    m_step = batch_VI_sLDA_M_Step(K, input_data_x, input_data_y,
                                  new_alpha, new_xi, new_eta, new_delta, new_Lambda,
                                  new_gamma, new_phi,
                                  len(input_data_y), epsilon)
    new_Lambda, new_alpha, new_xi, new_eta, new_delta, new_elbo = m_step.run(optimize_alpha_and_xi=True)
    improve_in_elbo = pct_diff(elbo_vs_time[-1], new_elbo)
    elbo_vs_time.append(new_elbo)
    j += 1
    for var in ['Lambda', 'alpha', 'xi', 'eta', 'delta']:
        pickle.dump(eval("new_"+var), open(output_dir + "/warmup_{0}_{1}.pickle".format(var, j), "wb"))
    print("Batch mode variational EM iteration {}: elbo =".format(j), new_elbo)
# Out:
# Batch mode variational EM iteration 1: elbo = -2190661.211389065
# Batch mode variational EM iteration 2: elbo = -1723427.261460781
# Batch mode variational EM iteration 3: elbo = -1600447.5615377426
# Batch mode variational EM iteration 4: elbo = -1546051.5418572426
# Batch mode variational EM iteration 5: elbo = -1515042.7995724678
# Batch mode variational EM iteration 6: elbo = -1494715.5532484055
# Batch mode variational EM iteration 7: elbo = -1480449.1903510094
# Batch mode variational EM iteration 8: elbo = -1469175.4657053947
# Batch mode variational EM iteration 9: elbo = -1460024.687148571
# Batch mode variational EM iteration 10: elbo = -1452529.3767814636
# Batch mode variational EM iteration 11: elbo = -1446254.727973938
# Batch mode variational EM iteration 12: elbo = -1440586.4481720924
# Batch mode variational EM iteration 13: elbo = -1435814.3432745934
# Batch mode variational EM iteration 14: elbo = -1431676.9727692604
# Batch mode variational EM iteration 15: elbo = -1427978.7786524296
# Batch mode variational EM iteration 16: elbo = -1424696.1104745865
# Batch mode variational EM iteration 17: elbo = -1421921.7933516502
# Batch mode variational EM iteration 18: elbo = -1419373.710140705
# Batch mode variational EM iteration 19: elbo = -1417044.7217755318
# Batch mode variational EM iteration 20: elbo = -1415068.237720728
# Batch mode variational EM iteration 21: elbo = -1413230.7936599255
# Batch mode variational EM iteration 22: elbo = -1411563.9625132084
# Batch mode variational EM iteration 23: elbo = -1409983.0862240791
# Batch mode variational EM iteration 24: elbo = -1408468.1071679592
# Batch mode variational EM iteration 25: elbo = -1407013.1090579033
# Batch mode variational EM iteration 26: elbo = -1405644.9051923752
# Batch mode variational EM iteration 27: elbo = -1404355.767076254
# Batch mode variational EM iteration 28: elbo = -1403174.237462759
# Batch mode variational EM iteration 29: elbo = -1402082.3782393932
# Batch mode variational EM iteration 30: elbo = -1401052.5467674732
# Batch mode variational EM iteration 31: elbo = -1400070.6317362785
# Batch mode variational EM iteration 32: elbo = -1399131.187218666
# Batch mode variational EM iteration 33: elbo = -1398236.54114151
# Batch mode variational EM iteration 34: elbo = -1397379.7555339336
# Batch mode variational EM iteration 35: elbo = -1396564.1979663372
# Batch mode variational EM iteration 36: elbo = -1395814.9367229939
# Batch mode variational EM iteration 37: elbo = -1395036.7625083923
# Batch mode variational EM iteration 38: elbo = -1394304.6214437485
# Batch mode variational EM iteration 39: elbo = -1393594.4551548958
# Batch mode variational EM iteration 40: elbo = -1392907.6637499332
# Batch mode variational EM iteration 41: elbo = -1392255.40218544
# Batch mode variational EM iteration 42: elbo = -1391619.5486268997
# Batch mode variational EM iteration 43: elbo = -1391000.6593120098
# Batch mode variational EM iteration 44: elbo = -1390387.7973423004
# Batch mode variational EM iteration 45: elbo = -1389791.8359197378
# Batch mode variational EM iteration 46: elbo = -1389217.1499255896
# Batch mode variational EM iteration 47: elbo = -1388666.8738763332
# Batch mode variational EM iteration 48: elbo = -1388107.9482207298
# Batch mode variational EM iteration 49: elbo = -1387569.1609733105
# Batch mode variational EM iteration 50: elbo = -1387042.3044817448
# Batch mode variational EM iteration 51: elbo = -1386511.0158013105
# Batch mode variational EM iteration 52: elbo = -1385998.1232438087
# Batch mode variational EM iteration 53: elbo = -1385489.5462779999
# Batch mode variational EM iteration 54: elbo = -1384990.655381322
# Batch mode variational EM iteration 55: elbo = -1384500.4952625036
# Batch mode variational EM iteration 56: elbo = -1384017.7300890684
# Batch mode variational EM iteration 57: elbo = -1383542.97777462
# Batch mode variational EM iteration 58: elbo = -1383090.1142460108
# Batch mode variational EM iteration 59: elbo = -1382659.1681455374
# Batch mode variational EM iteration 60: elbo = -1382233.5461124182
# Batch mode variational EM iteration 61: elbo = -1381814.6321732998
# Batch mode variational EM iteration 62: elbo = -1381400.4910094738
# Batch mode variational EM iteration 63: elbo = -1380999.5586724281
# Batch mode variational EM iteration 64: elbo = -1380592.5210443735
# Batch mode variational EM iteration 65: elbo = -1380192.5318541527
# Batch mode variational EM iteration 66: elbo = -1379807.5240119696
# Batch mode variational EM iteration 67: elbo = -1379423.1291573048
# Batch mode variational EM iteration 68: elbo = -1379048.643883109
# Batch mode variational EM iteration 69: elbo = -1378685.9646017551
# Batch mode variational EM iteration 70: elbo = -1378323.22371459
# Batch mode variational EM iteration 71: elbo = -1377967.894117713
# Batch mode variational EM iteration 72: elbo = -1377612.4782569408
# Batch mode variational EM iteration 73: elbo = -1377266.2671468258
# Batch mode variational EM iteration 74: elbo = -1376925.0973742008
# Batch mode variational EM iteration 75: elbo = -1376591.781641841
# Batch mode variational EM iteration 76: elbo = -1376264.5707250834
# Batch mode variational EM iteration 77: elbo = -1375945.125116825
# Batch mode variational EM iteration 78: elbo = -1375628.4504511356
# Batch mode variational EM iteration 79: elbo = -1375318.5451574326
# Batch mode variational EM iteration 80: elbo = -1375014.0695450306
# Batch mode variational EM iteration 81: elbo = -1374717.1275115013
# Batch mode variational EM iteration 82: elbo = -1374424.147090435
# Batch mode variational EM iteration 83: elbo = -1374137.7285602093
# Batch mode variational EM iteration 84: elbo = -1373858.7663823366
# Batch mode variational EM iteration 85: elbo = -1373590.2871857882
# Batch mode variational EM iteration 86: elbo = -1373329.3375675678
# Batch mode variational EM iteration 87: elbo = -1373074.1575068235
# Batch mode variational EM iteration 88: elbo = -1372821.2332099676
# Batch mode variational EM iteration 89: elbo = -1372569.0897156
# Batch mode variational EM iteration 90: elbo = -1372318.9739187956
# Batch mode variational EM iteration 91: elbo = -1372074.3833880424
# Batch mode variational EM iteration 92: elbo = -1371834.9609971046
# Batch mode variational EM iteration 93: elbo = -1371603.7176032066
# Batch mode variational EM iteration 94: elbo = -1371377.8061591387
# Batch mode variational EM iteration 95: elbo = -1371151.8444256783
# Batch mode variational EM iteration 96: elbo = -1370926.973850727
# Batch mode variational EM iteration 97: elbo = -1370712.932874322
# Batch mode variational EM iteration 98: elbo = -1370508.898918867
# Batch mode variational EM iteration 99: elbo = -1370312.0736198425
# Batch mode variational EM iteration 100: elbo = -1370116.0470825434
# Batch mode variational EM iteration 101: elbo = -1369926.6559587717
# Batch mode variational EM iteration 102: elbo = -1369740.4027023315
# Batch mode variational EM iteration 103: elbo = -1369563.8732001781
# Batch mode variational EM iteration 104: elbo = -1369386.3224585056
# Batch mode variational EM iteration 105: elbo = -1369216.3771115541
# Batch mode variational EM iteration 106: elbo = -1369055.1684014797
# Batch mode variational EM iteration 107: elbo = -1368903.6004111767
# Batch mode variational EM iteration 108: elbo = -1368756.0341849327
# Batch mode variational EM iteration 109: elbo = -1368609.3184498549
# Batch mode variational EM iteration 110: elbo = -1368465.6537704468
# Batch mode variational EM iteration 111: elbo = -1368330.3779110909

# %%
## Run minibatch (stochastic) mode variational EM
np.random.seed(654321)
delete_all_files(fpath[:-1])
S = 500 # set the minibatch size
n_iter_batch = len(pickle.load(open("/content/drive/MyDrive/batch_VI_sLDA_movie_rating/K_{}/elbo_vs_time.pickle".format(K), "rb")))
n_iter = int((3*n_iter_batch+1) * len(train_bow) / S) # total # of iterations of minibatch variational EM: equivalent to 3 times of the number of full passes of training data needed for the batch variational EM to converge
temp = S * np.arange(1,n_iter+1) // len(train_bow)
check_points = [np.arange(1,n_iter+1)[temp == i][0] for i in range(1, 3*n_iter_batch+1)]  # minibatch iterations that correspond to each iteration in batch mode
j = 0
switch_point = int(j * initial_batch_size / S) + 1    ## save parameters to Google Drive
check_points = np.array(check_points)
check_points = check_points[check_points >= switch_point]
check_points = {int(val):(i+1) for i,val in enumerate(check_points)}
kappa = 0.6 # "forgetting rate"
tau = 1 # "delay"

for t in range(switch_point, n_iter+1):

    ### randomly sample a minibatch with size S
    sample_indices = np.random.choice(np.arange(len(train_bow)), S, replace=False)
    train_bow_sample = {new_i:train_bow[new_i] for new_i,i in enumerate(sample_indices)}
    train_y_sample = train_y[sample_indices]
    input_data_x = train_bow_sample
    input_data_y = train_y_sample

    ### Run one iteration of E step (parallelized)
    # %run -i "parallelized_sLDA_E_step.py"
    all_gamma = [pickle.load(open(fn, "rb")) for fn in glob.glob(fpath + "gamma*")]
    new_gamma_dict = merge_dict(all_gamma)
    new_gamma = create_gamma_matrix(new_gamma_dict)
    all_phi = [pickle.load(open(fn, "rb")) for fn in glob.glob(fpath + "phi*")]
    new_phi = merge_dict(all_phi)

    ### Run one iteration of M step
    rho = step_size(t,tau,kappa) # rho_t
    m_step = VI_sLDA_M_Step(K, train_bow_sample, train_y_sample,
                            new_alpha, new_xi, new_eta, new_delta, new_Lambda,
                            new_gamma, new_phi,
                            len(train_bow), rho)
    new_Lambda, new_alpha, new_xi, new_eta, new_delta = m_step.run(update_alpha_and_xi = True)
    if t in check_points:
       for var in ['Lambda', 'alpha', 'xi', 'eta', 'delta']:
           pickle.dump(eval("new_"+var), open(output_dir + "/{0}_{1}.pickle".format(var, check_points[t]), "wb"))
    print("Stochastic (minibatch) variational EM iteration {} complete!".format(t-switch_point+1))
for var in ['Lambda', 'alpha', 'xi', 'eta', 'delta']:
    pickle.dump(eval("new_"+var), open(output_dir + "/{}.pickle".format(var), "wb"))
# Out:
# Stochastic (minibatch) variational EM iteration 1 complete!
# Stochastic (minibatch) variational EM iteration 2 complete!
# Stochastic (minibatch) variational EM iteration 3 complete!
# Stochastic (minibatch) variational EM iteration 4 complete!
# Stochastic (minibatch) variational EM iteration 5 complete!
# Stochastic (minibatch) variational EM iteration 6 complete!
# Stochastic (minibatch) variational EM iteration 7 complete!
# Stochastic (minibatch) variational EM iteration 8 complete!
# Stochastic (minibatch) variational EM iteration 9 complete!
# Stochastic (minibatch) variational EM iteration 10 complete!
# Stochastic (minibatch) variational EM iteration 11 complete!
# Stochastic (minibatch) variational EM iteration 12 complete!
# Stochastic (minibatch) variational EM iteration 13 complete!
# Stochastic (minibatch) variational EM iteration 14 complete!
# Stochastic (minibatch) variational EM iteration 15 complete!
# Stochastic (minibatch) variational EM iteration 16 complete!
# Stochastic (minibatch) variational EM iteration 17 complete!
# Stochastic (minibatch) variational EM iteration 18 complete!
# Stochastic (minibatch) variational EM iteration 19 complete!
# Stochastic (minibatch) variational EM iteration 20 complete!
# Stochastic (minibatch) variational EM iteration 21 complete!
# Stochastic (minibatch) variational EM iteration 22 complete!
# Stochastic (minibatch) variational EM iteration 23 complete!
# Stochastic (minibatch) variational EM iteration 24 complete!
# Stochastic (minibatch) variational EM iteration 25 complete!
# Stochastic (minibatch) variational EM iteration 26 complete!
# Stochastic (minibatch) variational EM iteration 27 complete!
# Stochastic (minibatch) variational EM iteration 28 complete!
# Stochastic (minibatch) variational EM iteration 29 complete!
# Stochastic (minibatch) variational EM iteration 30 complete!
# Stochastic (minibatch) variational EM iteration 31 complete!
# Stochastic (minibatch) variational EM iteration 32 complete!
# Stochastic (minibatch) variational EM iteration 33 complete!
# Stochastic (minibatch) variational EM iteration 34 complete!
# Stochastic (minibatch) variational EM iteration 35 complete!
# Stochastic (minibatch) variational EM iteration 36 complete!
# Stochastic (minibatch) variational EM iteration 37 complete!
# Stochastic (minibatch) variational EM iteration 38 complete!
# Stochastic (minibatch) variational EM iteration 39 complete!
# Stochastic (minibatch) variational EM iteration 40 complete!
# Stochastic (minibatch) variational EM iteration 41 complete!
# Stochastic (minibatch) variational EM iteration 42 complete!
# Stochastic (minibatch) variational EM iteration 43 complete!
# Stochastic (minibatch) variational EM iteration 44 complete!
# Stochastic (minibatch) variational EM iteration 45 complete!
# Stochastic (minibatch) variational EM iteration 46 complete!
# Stochastic (minibatch) variational EM iteration 47 complete!
# Stochastic (minibatch) variational EM iteration 48 complete!
# Stochastic (minibatch) variational EM iteration 49 complete!
# Stochastic (minibatch) variational EM iteration 50 complete!
# Stochastic (minibatch) variational EM iteration 51 complete!
# Stochastic (minibatch) variational EM iteration 52 complete!
# Stochastic (minibatch) variational EM iteration 53 complete!
# Stochastic (minibatch) variational EM iteration 54 complete!
# Stochastic (minibatch) variational EM iteration 55 complete!
# Stochastic (minibatch) variational EM iteration 56 complete!
# Stochastic (minibatch) variational EM iteration 57 complete!
# Stochastic (minibatch) variational EM iteration 58 complete!
# Stochastic (minibatch) variational EM iteration 59 complete!
# Stochastic (minibatch) variational EM iteration 60 complete!
# Stochastic (minibatch) variational EM iteration 61 complete!
# Stochastic (minibatch) variational EM iteration 62 complete!
# Stochastic (minibatch) variational EM iteration 63 complete!
# Stochastic (minibatch) variational EM iteration 64 complete!
# Stochastic (minibatch) variational EM iteration 65 complete!
# Stochastic (minibatch) variational EM iteration 66 complete!
# Stochastic (minibatch) variational EM iteration 67 complete!
# Stochastic (minibatch) variational EM iteration 68 complete!
# Stochastic (minibatch) variational EM iteration 69 complete!
# Stochastic (minibatch) variational EM iteration 70 complete!
# Stochastic (minibatch) variational EM iteration 71 complete!
# Stochastic (minibatch) variational EM iteration 72 complete!
# Stochastic (minibatch) variational EM iteration 73 complete!
# Stochastic (minibatch) variational EM iteration 74 complete!
# Stochastic (minibatch) variational EM iteration 75 complete!
# Stochastic (minibatch) variational EM iteration 76 complete!
# Stochastic (minibatch) variational EM iteration 77 complete!
# Stochastic (minibatch) variational EM iteration 78 complete!
# Stochastic (minibatch) variational EM iteration 79 complete!
# Stochastic (minibatch) variational EM iteration 80 complete!
# Stochastic (minibatch) variational EM iteration 81 complete!
# Stochastic (minibatch) variational EM iteration 82 complete!
# Stochastic (minibatch) variational EM iteration 83 complete!
# Stochastic (minibatch) variational EM iteration 84 complete!
# Stochastic (minibatch) variational EM iteration 85 complete!
# Stochastic (minibatch) variational EM iteration 86 complete!
# Stochastic (minibatch) variational EM iteration 87 complete!
# Stochastic (minibatch) variational EM iteration 88 complete!
# Stochastic (minibatch) variational EM iteration 89 complete!
# Stochastic (minibatch) variational EM iteration 90 complete!
# Stochastic (minibatch) variational EM iteration 91 complete!
# Stochastic (minibatch) variational EM iteration 92 complete!
# Stochastic (minibatch) variational EM iteration 93 complete!
# Stochastic (minibatch) variational EM iteration 94 complete!
# Stochastic (minibatch) variational EM iteration 95 complete!
# Stochastic (minibatch) variational EM iteration 96 complete!
# Stochastic (minibatch) variational EM iteration 97 complete!
# Stochastic (minibatch) variational EM iteration 98 complete!
# Stochastic (minibatch) variational EM iteration 99 complete!
# Stochastic (minibatch) variational EM iteration 100 complete!
# Stochastic (minibatch) variational EM iteration 101 complete!
# Stochastic (minibatch) variational EM iteration 102 complete!
# Stochastic (minibatch) variational EM iteration 103 complete!
# Stochastic (minibatch) variational EM iteration 104 complete!
# Stochastic (minibatch) variational EM iteration 105 complete!
# Stochastic (minibatch) variational EM iteration 106 complete!
# Stochastic (minibatch) variational EM iteration 107 complete!
# Stochastic (minibatch) variational EM iteration 108 complete!
# Stochastic (minibatch) variational EM iteration 109 complete!
# Stochastic (minibatch) variational EM iteration 110 complete!
# Stochastic (minibatch) variational EM iteration 111 complete!
# Stochastic (minibatch) variational EM iteration 112 complete!
# Stochastic (minibatch) variational EM iteration 113 complete!
# Stochastic (minibatch) variational EM iteration 114 complete!
# Stochastic (minibatch) variational EM iteration 115 complete!
# Stochastic (minibatch) variational EM iteration 116 complete!
# Stochastic (minibatch) variational EM iteration 117 complete!
# Stochastic (minibatch) variational EM iteration 118 complete!
# Stochastic (minibatch) variational EM iteration 119 complete!
# Stochastic (minibatch) variational EM iteration 120 complete!
# Stochastic (minibatch) variational EM iteration 121 complete!
# Stochastic (minibatch) variational EM iteration 122 complete!
# Stochastic (minibatch) variational EM iteration 123 complete!
# Stochastic (minibatch) variational EM iteration 124 complete!
# Stochastic (minibatch) variational EM iteration 125 complete!
# Stochastic (minibatch) variational EM iteration 126 complete!
# Stochastic (minibatch) variational EM iteration 127 complete!
# Stochastic (minibatch) variational EM iteration 128 complete!
# Stochastic (minibatch) variational EM iteration 129 complete!
# Stochastic (minibatch) variational EM iteration 130 complete!
# Stochastic (minibatch) variational EM iteration 131 complete!
# Stochastic (minibatch) variational EM iteration 132 complete!
# Stochastic (minibatch) variational EM iteration 133 complete!
# Stochastic (minibatch) variational EM iteration 134 complete!
# Stochastic (minibatch) variational EM iteration 135 complete!
# Stochastic (minibatch) variational EM iteration 136 complete!
# Stochastic (minibatch) variational EM iteration 137 complete!
# Stochastic (minibatch) variational EM iteration 138 complete!
# Stochastic (minibatch) variational EM iteration 139 complete!
# Stochastic (minibatch) variational EM iteration 140 complete!
# Stochastic (minibatch) variational EM iteration 141 complete!
# Stochastic (minibatch) variational EM iteration 142 complete!
# Stochastic (minibatch) variational EM iteration 143 complete!
# Stochastic (minibatch) variational EM iteration 144 complete!
# Stochastic (minibatch) variational EM iteration 145 complete!
# Stochastic (minibatch) variational EM iteration 146 complete!
# Stochastic (minibatch) variational EM iteration 147 complete!
# Stochastic (minibatch) variational EM iteration 148 complete!
# Stochastic (minibatch) variational EM iteration 149 complete!
# Stochastic (minibatch) variational EM iteration 150 complete!
# Stochastic (minibatch) variational EM iteration 151 complete!
# Stochastic (minibatch) variational EM iteration 152 complete!
# Stochastic (minibatch) variational EM iteration 153 complete!
# Stochastic (minibatch) variational EM iteration 154 complete!
# Stochastic (minibatch) variational EM iteration 155 complete!
# Stochastic (minibatch) variational EM iteration 156 complete!
# Stochastic (minibatch) variational EM iteration 157 complete!
# Stochastic (minibatch) variational EM iteration 158 complete!
# Stochastic (minibatch) variational EM iteration 159 complete!
# Stochastic (minibatch) variational EM iteration 160 complete!
# Stochastic (minibatch) variational EM iteration 161 complete!
# Stochastic (minibatch) variational EM iteration 162 complete!
# Stochastic (minibatch) variational EM iteration 163 complete!
# Stochastic (minibatch) variational EM iteration 164 complete!
# Stochastic (minibatch) variational EM iteration 165 complete!
# Stochastic (minibatch) variational EM iteration 166 complete!
# Stochastic (minibatch) variational EM iteration 167 complete!
# Stochastic (minibatch) variational EM iteration 168 complete!
# Stochastic (minibatch) variational EM iteration 169 complete!
# Stochastic (minibatch) variational EM iteration 170 complete!
# Stochastic (minibatch) variational EM iteration 171 complete!
# Stochastic (minibatch) variational EM iteration 172 complete!
# Stochastic (minibatch) variational EM iteration 173 complete!
# Stochastic (minibatch) variational EM iteration 174 complete!
# Stochastic (minibatch) variational EM iteration 175 complete!
# Stochastic (minibatch) variational EM iteration 176 complete!
# Stochastic (minibatch) variational EM iteration 177 complete!
# Stochastic (minibatch) variational EM iteration 178 complete!
# Stochastic (minibatch) variational EM iteration 179 complete!
# Stochastic (minibatch) variational EM iteration 180 complete!
# Stochastic (minibatch) variational EM iteration 181 complete!
# Stochastic (minibatch) variational EM iteration 182 complete!
# Stochastic (minibatch) variational EM iteration 183 complete!
# Stochastic (minibatch) variational EM iteration 184 complete!
# Stochastic (minibatch) variational EM iteration 185 complete!
# Stochastic (minibatch) variational EM iteration 186 complete!
# Stochastic (minibatch) variational EM iteration 187 complete!
# Stochastic (minibatch) variational EM iteration 188 complete!
# Stochastic (minibatch) variational EM iteration 189 complete!
# Stochastic (minibatch) variational EM iteration 190 complete!
# Stochastic (minibatch) variational EM iteration 191 complete!
# Stochastic (minibatch) variational EM iteration 192 complete!
# Stochastic (minibatch) variational EM iteration 193 complete!
# Stochastic (minibatch) variational EM iteration 194 complete!
# Stochastic (minibatch) variational EM iteration 195 complete!
# Stochastic (minibatch) variational EM iteration 196 complete!
# Stochastic (minibatch) variational EM iteration 197 complete!
# Stochastic (minibatch) variational EM iteration 198 complete!
# Stochastic (minibatch) variational EM iteration 199 complete!
# Stochastic (minibatch) variational EM iteration 200 complete!
# Stochastic (minibatch) variational EM iteration 201 complete!
# Stochastic (minibatch) variational EM iteration 202 complete!
# Stochastic (minibatch) variational EM iteration 203 complete!
# Stochastic (minibatch) variational EM iteration 204 complete!
# Stochastic (minibatch) variational EM iteration 205 complete!
# Stochastic (minibatch) variational EM iteration 206 complete!
# Stochastic (minibatch) variational EM iteration 207 complete!
# Stochastic (minibatch) variational EM iteration 208 complete!
# Stochastic (minibatch) variational EM iteration 209 complete!
# Stochastic (minibatch) variational EM iteration 210 complete!
# Stochastic (minibatch) variational EM iteration 211 complete!
# Stochastic (minibatch) variational EM iteration 212 complete!
# Stochastic (minibatch) variational EM iteration 213 complete!
# Stochastic (minibatch) variational EM iteration 214 complete!
# Stochastic (minibatch) variational EM iteration 215 complete!
# Stochastic (minibatch) variational EM iteration 216 complete!
# Stochastic (minibatch) variational EM iteration 217 complete!
# Stochastic (minibatch) variational EM iteration 218 complete!
# Stochastic (minibatch) variational EM iteration 219 complete!
# Stochastic (minibatch) variational EM iteration 220 complete!
# Stochastic (minibatch) variational EM iteration 221 complete!
# Stochastic (minibatch) variational EM iteration 222 complete!
# Stochastic (minibatch) variational EM iteration 223 complete!
# Stochastic (minibatch) variational EM iteration 224 complete!
# Stochastic (minibatch) variational EM iteration 225 complete!
# Stochastic (minibatch) variational EM iteration 226 complete!
# Stochastic (minibatch) variational EM iteration 227 complete!
# Stochastic (minibatch) variational EM iteration 228 complete!
# Stochastic (minibatch) variational EM iteration 229 complete!
# Stochastic (minibatch) variational EM iteration 230 complete!
# Stochastic (minibatch) variational EM iteration 231 complete!
# Stochastic (minibatch) variational EM iteration 232 complete!
# Stochastic (minibatch) variational EM iteration 233 complete!
# Stochastic (minibatch) variational EM iteration 234 complete!
# Stochastic (minibatch) variational EM iteration 235 complete!
# Stochastic (minibatch) variational EM iteration 236 complete!
# Stochastic (minibatch) variational EM iteration 237 complete!
# Stochastic (minibatch) variational EM iteration 238 complete!
# Stochastic (minibatch) variational EM iteration 239 complete!
# Stochastic (minibatch) variational EM iteration 240 complete!
# Stochastic (minibatch) variational EM iteration 241 complete!
# Stochastic (minibatch) variational EM iteration 242 complete!
# Stochastic (minibatch) variational EM iteration 243 complete!
# Stochastic (minibatch) variational EM iteration 244 complete!
# Stochastic (minibatch) variational EM iteration 245 complete!
# Stochastic (minibatch) variational EM iteration 246 complete!
# Stochastic (minibatch) variational EM iteration 247 complete!
# Stochastic (minibatch) variational EM iteration 248 complete!
# Stochastic (minibatch) variational EM iteration 249 complete!
# Stochastic (minibatch) variational EM iteration 250 complete!
# Stochastic (minibatch) variational EM iteration 251 complete!
# Stochastic (minibatch) variational EM iteration 252 complete!
# Stochastic (minibatch) variational EM iteration 253 complete!
# Stochastic (minibatch) variational EM iteration 254 complete!
# Stochastic (minibatch) variational EM iteration 255 complete!
# Stochastic (minibatch) variational EM iteration 256 complete!
# Stochastic (minibatch) variational EM iteration 257 complete!
# Stochastic (minibatch) variational EM iteration 258 complete!
# Stochastic (minibatch) variational EM iteration 259 complete!
# Stochastic (minibatch) variational EM iteration 260 complete!
# Stochastic (minibatch) variational EM iteration 261 complete!
# Stochastic (minibatch) variational EM iteration 262 complete!
# Stochastic (minibatch) variational EM iteration 263 complete!
# Stochastic (minibatch) variational EM iteration 264 complete!
# Stochastic (minibatch) variational EM iteration 265 complete!
# Stochastic (minibatch) variational EM iteration 266 complete!
# Stochastic (minibatch) variational EM iteration 267 complete!
# Stochastic (minibatch) variational EM iteration 268 complete!
# Stochastic (minibatch) variational EM iteration 269 complete!
# Stochastic (minibatch) variational EM iteration 270 complete!
# Stochastic (minibatch) variational EM iteration 271 complete!
# Stochastic (minibatch) variational EM iteration 272 complete!
# Stochastic (minibatch) variational EM iteration 273 complete!
# Stochastic (minibatch) variational EM iteration 274 complete!
# Stochastic (minibatch) variational EM iteration 275 complete!
# Stochastic (minibatch) variational EM iteration 276 complete!
# Stochastic (minibatch) variational EM iteration 277 complete!
# Stochastic (minibatch) variational EM iteration 278 complete!
# Stochastic (minibatch) variational EM iteration 279 complete!
# Stochastic (minibatch) variational EM iteration 280 complete!
# Stochastic (minibatch) variational EM iteration 281 complete!
# Stochastic (minibatch) variational EM iteration 282 complete!
# Stochastic (minibatch) variational EM iteration 283 complete!
# Stochastic (minibatch) variational EM iteration 284 complete!
# Stochastic (minibatch) variational EM iteration 285 complete!
# Stochastic (minibatch) variational EM iteration 286 complete!
# Stochastic (minibatch) variational EM iteration 287 complete!
# Stochastic (minibatch) variational EM iteration 288 complete!
# Stochastic (minibatch) variational EM iteration 289 complete!
# Stochastic (minibatch) variational EM iteration 290 complete!
# Stochastic (minibatch) variational EM iteration 291 complete!
# Stochastic (minibatch) variational EM iteration 292 complete!
# Stochastic (minibatch) variational EM iteration 293 complete!
# Stochastic (minibatch) variational EM iteration 294 complete!
# Stochastic (minibatch) variational EM iteration 295 complete!
# Stochastic (minibatch) variational EM iteration 296 complete!
# Stochastic (minibatch) variational EM iteration 297 complete!
# Stochastic (minibatch) variational EM iteration 298 complete!
# Stochastic (minibatch) variational EM iteration 299 complete!
# Stochastic (minibatch) variational EM iteration 300 complete!
# Stochastic (minibatch) variational EM iteration 301 complete!
# Stochastic (minibatch) variational EM iteration 302 complete!
# Stochastic (minibatch) variational EM iteration 303 complete!
# Stochastic (minibatch) variational EM iteration 304 complete!
# Stochastic (minibatch) variational EM iteration 305 complete!
# Stochastic (minibatch) variational EM iteration 306 complete!
# Stochastic (minibatch) variational EM iteration 307 complete!
# Stochastic (minibatch) variational EM iteration 308 complete!
# Stochastic (minibatch) variational EM iteration 309 complete!
# Stochastic (minibatch) variational EM iteration 310 complete!
# Stochastic (minibatch) variational EM iteration 311 complete!
# Stochastic (minibatch) variational EM iteration 312 complete!
# Stochastic (minibatch) variational EM iteration 313 complete!
# Stochastic (minibatch) variational EM iteration 314 complete!
# Stochastic (minibatch) variational EM iteration 315 complete!
# Stochastic (minibatch) variational EM iteration 316 complete!
# Stochastic (minibatch) variational EM iteration 317 complete!
# Stochastic (minibatch) variational EM iteration 318 complete!
# Stochastic (minibatch) variational EM iteration 319 complete!
# Stochastic (minibatch) variational EM iteration 320 complete!
# Stochastic (minibatch) variational EM iteration 321 complete!
# Stochastic (minibatch) variational EM iteration 322 complete!
# Stochastic (minibatch) variational EM iteration 323 complete!
# Stochastic (minibatch) variational EM iteration 324 complete!
# Stochastic (minibatch) variational EM iteration 325 complete!
# Stochastic (minibatch) variational EM iteration 326 complete!
# Stochastic (minibatch) variational EM iteration 327 complete!
# Stochastic (minibatch) variational EM iteration 328 complete!
# Stochastic (minibatch) variational EM iteration 329 complete!
# Stochastic (minibatch) variational EM iteration 330 complete!
# Stochastic (minibatch) variational EM iteration 331 complete!
# Stochastic (minibatch) variational EM iteration 332 complete!
# Stochastic (minibatch) variational EM iteration 333 complete!
# Stochastic (minibatch) variational EM iteration 334 complete!
# Stochastic (minibatch) variational EM iteration 335 complete!
# Stochastic (minibatch) variational EM iteration 336 complete!
# Stochastic (minibatch) variational EM iteration 337 complete!
# Stochastic (minibatch) variational EM iteration 338 complete!
# Stochastic (minibatch) variational EM iteration 339 complete!
# Stochastic (minibatch) variational EM iteration 340 complete!
# Stochastic (minibatch) variational EM iteration 341 complete!
# Stochastic (minibatch) variational EM iteration 342 complete!
# Stochastic (minibatch) variational EM iteration 343 complete!
# Stochastic (minibatch) variational EM iteration 344 complete!
# Stochastic (minibatch) variational EM iteration 345 complete!
# Stochastic (minibatch) variational EM iteration 346 complete!
# Stochastic (minibatch) variational EM iteration 347 complete!
# Stochastic (minibatch) variational EM iteration 348 complete!
# Stochastic (minibatch) variational EM iteration 349 complete!
# Stochastic (minibatch) variational EM iteration 350 complete!
# Stochastic (minibatch) variational EM iteration 351 complete!
# Stochastic (minibatch) variational EM iteration 352 complete!
# Stochastic (minibatch) variational EM iteration 353 complete!
# Stochastic (minibatch) variational EM iteration 354 complete!
# Stochastic (minibatch) variational EM iteration 355 complete!
# Stochastic (minibatch) variational EM iteration 356 complete!
# Stochastic (minibatch) variational EM iteration 357 complete!
# Stochastic (minibatch) variational EM iteration 358 complete!
# Stochastic (minibatch) variational EM iteration 359 complete!
# Stochastic (minibatch) variational EM iteration 360 complete!
# Stochastic (minibatch) variational EM iteration 361 complete!
# Stochastic (minibatch) variational EM iteration 362 complete!
# Stochastic (minibatch) variational EM iteration 363 complete!
# Stochastic (minibatch) variational EM iteration 364 complete!
# Stochastic (minibatch) variational EM iteration 365 complete!
# Stochastic (minibatch) variational EM iteration 366 complete!
# Stochastic (minibatch) variational EM iteration 367 complete!
# Stochastic (minibatch) variational EM iteration 368 complete!
# Stochastic (minibatch) variational EM iteration 369 complete!
# Stochastic (minibatch) variational EM iteration 370 complete!
# Stochastic (minibatch) variational EM iteration 371 complete!
# Stochastic (minibatch) variational EM iteration 372 complete!
# Stochastic (minibatch) variational EM iteration 373 complete!
# Stochastic (minibatch) variational EM iteration 374 complete!
# Stochastic (minibatch) variational EM iteration 375 complete!
# Stochastic (minibatch) variational EM iteration 376 complete!
# Stochastic (minibatch) variational EM iteration 377 complete!
# Stochastic (minibatch) variational EM iteration 378 complete!
# Stochastic (minibatch) variational EM iteration 379 complete!
# Stochastic (minibatch) variational EM iteration 380 complete!
# Stochastic (minibatch) variational EM iteration 381 complete!
# Stochastic (minibatch) variational EM iteration 382 complete!
# Stochastic (minibatch) variational EM iteration 383 complete!
# Stochastic (minibatch) variational EM iteration 384 complete!
# Stochastic (minibatch) variational EM iteration 385 complete!
# Stochastic (minibatch) variational EM iteration 386 complete!
# Stochastic (minibatch) variational EM iteration 387 complete!
# Stochastic (minibatch) variational EM iteration 388 complete!
# Stochastic (minibatch) variational EM iteration 389 complete!
# Stochastic (minibatch) variational EM iteration 390 complete!
# Stochastic (minibatch) variational EM iteration 391 complete!
# Stochastic (minibatch) variational EM iteration 392 complete!
# Stochastic (minibatch) variational EM iteration 393 complete!
# Stochastic (minibatch) variational EM iteration 394 complete!
# Stochastic (minibatch) variational EM iteration 395 complete!
# Stochastic (minibatch) variational EM iteration 396 complete!
# Stochastic (minibatch) variational EM iteration 397 complete!
# Stochastic (minibatch) variational EM iteration 398 complete!
# Stochastic (minibatch) variational EM iteration 399 complete!
# Stochastic (minibatch) variational EM iteration 400 complete!
# Stochastic (minibatch) variational EM iteration 401 complete!
# Stochastic (minibatch) variational EM iteration 402 complete!
# Stochastic (minibatch) variational EM iteration 403 complete!
# Stochastic (minibatch) variational EM iteration 404 complete!
# Stochastic (minibatch) variational EM iteration 405 complete!
# Stochastic (minibatch) variational EM iteration 406 complete!
# Stochastic (minibatch) variational EM iteration 407 complete!
# Stochastic (minibatch) variational EM iteration 408 complete!
# Stochastic (minibatch) variational EM iteration 409 complete!
# Stochastic (minibatch) variational EM iteration 410 complete!
# Stochastic (minibatch) variational EM iteration 411 complete!
# Stochastic (minibatch) variational EM iteration 412 complete!
# Stochastic (minibatch) variational EM iteration 413 complete!
# Stochastic (minibatch) variational EM iteration 414 complete!
# Stochastic (minibatch) variational EM iteration 415 complete!
# Stochastic (minibatch) variational EM iteration 416 complete!
# Stochastic (minibatch) variational EM iteration 417 complete!
# Stochastic (minibatch) variational EM iteration 418 complete!
# Stochastic (minibatch) variational EM iteration 419 complete!
# Stochastic (minibatch) variational EM iteration 420 complete!
# Stochastic (minibatch) variational EM iteration 421 complete!
# Stochastic (minibatch) variational EM iteration 422 complete!
# Stochastic (minibatch) variational EM iteration 423 complete!
# Stochastic (minibatch) variational EM iteration 424 complete!
# Stochastic (minibatch) variational EM iteration 425 complete!
# Stochastic (minibatch) variational EM iteration 426 complete!
# Stochastic (minibatch) variational EM iteration 427 complete!
# Stochastic (minibatch) variational EM iteration 428 complete!
# Stochastic (minibatch) variational EM iteration 429 complete!
# Stochastic (minibatch) variational EM iteration 430 complete!
# Stochastic (minibatch) variational EM iteration 431 complete!
# Stochastic (minibatch) variational EM iteration 432 complete!
# Stochastic (minibatch) variational EM iteration 433 complete!
# Stochastic (minibatch) variational EM iteration 434 complete!
# Stochastic (minibatch) variational EM iteration 435 complete!
